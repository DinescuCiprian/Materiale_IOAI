# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Pentru a adauga un tabel in google colab folosim "comanda df = pd.read_csv(link)""

# %%
df = pd.read_csv('https://storage.googleapis.com/datasets-3456/loan_train_data.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df['ApplicantIncome'] * 2
# Out:
# 0      11698
# 1       9166
# 2       6000
# 3       5166
# 4      12000
#        ...
# 609     5800
# 610     8212
# 611    16144
# 612    15166
# 613     9166
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df['ApplicantIncome'] > 6000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611     True
# 612     True
# 613    False
# Name: ApplicantIncome, Length: 614, dtype: bool

# %%
# Comanda de mai jos mi-a afisat din lista de venituri doar veniturile mai mari
# decat 5000

# %%
df['ApplicantIncome'].loc[df['ApplicantIncome'] > 5000]
# Out:
# 0       5849
# 4       6000
# 5       5417
# 9      12841
# 20      7660
#        ...
# 599     5780
# 602     5703
# 604    12000
# 611     8072
# 612     7583
# Name: ApplicantIncome, Length: 191, dtype: int64

# %%
# Aceasta comanda afiseaza tabelul original(care nu a suferit modificari)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Property_Area']
# Out:
# 0          Urban
# 1          Rural
# 2          Urban
# 3          Urban
# 4          Urban
#          ...
# 609        Rural
# 610        Rural
# 611        Urban
# 612        Urban
# 613    Semiurban
# Name: Property_Area, Length: 614, dtype: object

# %%
# Aceasta comanda construieste un vector cu categoriile avute in coloana Property_Area

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
# Aceasta comanda imi numara toate afisariile pentru fiecare cotegorie

# %%
df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
# Acesta comanda imi construieste o diagrama conform datelor din coloana Property_Area

# %%
plt.bar([0,1,2], df['Property_Area'].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
# Aceasta comanda face o histograma a coloanei ApplicantIncome

# %%
plt.hist(df['ApplicantIncome'], bins=10)
# Out:
# (array([533.,  59.,  15.,   0.,   4.,   0.,   1.,   1.,   0.,   1.]),
#  array([  150.,  8235., 16320., 24405., 32490., 40575., 48660., 56745.,
#         64830., 72915., 81000.]),
#  <BarContainer object of 10 artists>)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# NaN means not a number

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
# Prin comanda de mai jos am creat o coloana noua numita GE la sfarsitul tabelui

# %%
df['GE'] = 0

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Prin comenzile de mai jos am pus in coloana noua numita GE valoarea 1
# daca in coloanda Gender avem Male si valoarea 2 daca avem Female

# %%
df.loc[df['Gender'] == 'Female', 'GE'] = 1
df.loc[df['Gender'] == 'Male', 'GE'] = 2

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Prin aceasta comanda am sters din tabel coloana Loan_ID si Gender

# %%
df.drop(columns=['Loan_ID', 'Gender'], inplace=True)

# %%
df
# Out:
#     Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0        No          0      Graduate            No             5849
# 1       Yes          1      Graduate            No             4583
# 2       Yes          0      Graduate           Yes             3000
# 3       Yes          0  Not Graduate            No             2583
# 4        No          0      Graduate            No             6000
# ..      ...        ...           ...           ...              ...
# 609      No          0      Graduate            No             2900
# 610     Yes         3+      Graduate            No             4106
# 611     Yes          1      Graduate            No             8072
# 612     Yes          2      Graduate            No             7583
# 613      No          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
df['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Married'].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
# Prin aceasta comanda am schimbat din coloana Married valoarea Yes cu 1 si valoarea No cu 0

# %%
df['Married'] = df['Married'].map({'Yes':1, 'No':0})

# %%
df
# Out:
#      Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0        0.0          0      Graduate            No             5849
# 1        1.0          1      Graduate            No             4583
# 2        1.0          0      Graduate           Yes             3000
# 3        1.0          0  Not Graduate            No             2583
# 4        0.0          0      Graduate            No             6000
# ..       ...        ...           ...           ...              ...
# 609      0.0          0      Graduate            No             2900
# 610      1.0         3+      Graduate            No             4106
# 611      1.0          1      Graduate            No             8072
# 612      1.0          2      Graduate            No             7583
# 613      0.0          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df['Dependents']= df['Dependents'].map({'0': 0, '1': 1, '2': 2, '3+': 3})

# %%
df
# Out:
#      Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0        0.0          0      Graduate            No             5849
# 1        1.0          1      Graduate            No             4583
# 2        1.0          0      Graduate           Yes             3000
# 3        1.0          0  Not Graduate            No             2583
# 4        0.0          0      Graduate            No             6000
# ..       ...        ...           ...           ...              ...
# 609      0.0          0      Graduate            No             2900
# 610      1.0         3+      Graduate            No             4106
# 611      1.0          1      Graduate            No             8072
# 612      1.0          2      Graduate            No             7583
# 613      0.0          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df['Education']
# Out:
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 609        Graduate
# 610        Graduate
# 611        Graduate
# 612        Graduate
# 613        Graduate
# Name: Education, Length: 614, dtype: object

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df['Education'] = df['Education'].map({'Graduate':1, 'Not Graduate':0})

# %%
df
# Out:
#      Married Dependents  Education Self_Employed  ApplicantIncome  \
# 0        0.0          0          1            No             5849
# 1        1.0          1          1            No             4583
# 2        1.0          0          1           Yes             3000
# 3        1.0          0          0            No             2583
# 4        0.0          0          1            No             6000
# ..       ...        ...        ...           ...              ...
# 609      0.0          0          1            No             2900
# 610      1.0         3+          1            No             4106
# 611      1.0          1          1            No             8072
# 612      1.0          2          1            No             7583
# 613      0.0          0          1           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
df['Property_Area']
# Out:
# 0          Urban
# 1          Rural
# 2          Urban
# 3          Urban
# 4          Urban
#          ...
# 609        Rural
# 610        Rural
# 611        Urban
# 612        Urban
# 613    Semiurban
# Name: Property_Area, Length: 614, dtype: object

# %%
df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
# Aceasta comanda a facut 3 coloane noi folosindu-se de categoriile din coloana Property_Area

# %%
df = pd.get_dummies(df, columns=['Property_Area'])

# %%
df
# Out:
#      Married Dependents  Education Self_Employed  ApplicantIncome  \
# 0        0.0          0          1            No             5849
# 1        1.0          1          1            No             4583
# 2        1.0          0          1           Yes             3000
# 3        1.0          0          0            No             2583
# 4        0.0          0          1            No             6000
# ..       ...        ...        ...           ...              ...
# 609      0.0          0          1            No             2900
# 610      1.0         3+          1            No             4106
# 611      1.0          1          1            No             8072
# 612      1.0          2          1            No             7583
# 613      0.0          0          1           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  611 non-null    float64
#  1   Dependents               599 non-null    object
#  2   Education                614 non-null    int64
#  3   Self_Employed            582 non-null    object
#  4   ApplicantIncome          614 non-null    int64
#  5   CoapplicantIncome        614 non-null    float64
#  6   LoanAmount               592 non-null    float64
#  7   Loan_Amount_Term         600 non-null    float64
#  8   Credit_History           564 non-null    float64
#  9   Loan_Status              614 non-null    object
#  10  GE                       614 non-null    int64
#  11  Property_Area_Rural      614 non-null    bool
#  12  Property_Area_Semiurban  614 non-null    bool
#  13  Property_Area_Urban      614 non-null    bool
# ...

# %%
df['LoanAmount']
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
# Aceasta comanda face media valoriilor din coloana LoanAmount

# %%
df['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
# Acesta comanda imi cauta in coloana selecatat daca am valori NaN, si daca gaseste una afiseaza True

# %%
df['LoanAmount'].isna()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Name: LoanAmount, Length: 614, dtype: bool

# %%
df.loc[df['LoanAmount'].isna(), 'LoanAmount'] = df['LoanAmount'].mean()

# %%
df
# Out:
#      Married Dependents  Education Self_Employed  ApplicantIncome  \
# 0        0.0          0          1            No             5849
# 1        1.0          1          1            No             4583
# 2        1.0          0          1           Yes             3000
# 3        1.0          0          0            No             2583
# 4        0.0          0          1            No             6000
# ..       ...        ...        ...           ...              ...
# 609      0.0          0          1            No             2900
# 610      1.0         3+          1            No             4106
# 611      1.0          1          1            No             8072
# 612      1.0          2          1            No             7583
# 613      0.0          0          1           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  611 non-null    float64
#  1   Dependents               599 non-null    object
#  2   Education                614 non-null    int64
#  3   Self_Employed            582 non-null    object
#  4   ApplicantIncome          614 non-null    int64
#  5   CoapplicantIncome        614 non-null    float64
#  6   LoanAmount               614 non-null    float64
#  7   Loan_Amount_Term         600 non-null    float64
#  8   Credit_History           564 non-null    float64
#  9   Loan_Status              614 non-null    object
#  10  GE                       614 non-null    int64
#  11  Property_Area_Rural      614 non-null    bool
#  12  Property_Area_Semiurban  614 non-null    bool
#  13  Property_Area_Urban      614 non-null    bool
# ...

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240., 342., 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 342.0     14
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
df.loc[df['Loan_Amount_Term'].isna(), 'Loan_Amount_Term'] = df['Loan_Amount_Term'].mean()

# %%
df
# Out:
#      Married Dependents  Education Self_Employed  ApplicantIncome  \
# 0        0.0          0          1            No             5849
# 1        1.0          1          1            No             4583
# 2        1.0          0          1           Yes             3000
# 3        1.0          0          0            No             2583
# 4        0.0          0          1            No             6000
# ..       ...        ...        ...           ...              ...
# 609      0.0          0          1            No             2900
# 610      1.0         3+          1            No             4106
# 611      1.0          1          1            No             8072
# 612      1.0          2          1            No             7583
# 613      0.0          0          1           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# ...

# %%
df['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
df.loc[df['Credit_History'].isna(), 'Credit_History'] = df['Credit_History'].mean()

# %%
df
# Out:
#      Married Dependents  Education Self_Employed  ApplicantIncome  \
# 0        0.0          0          1            No             5849
# 1        1.0          1          1            No             4583
# 2        1.0          0          1           Yes             3000
# 3        1.0          0          0            No             2583
# 4        0.0          0          1            No             6000
# ..       ...        ...        ...           ...              ...
# 609      0.0          0          1            No             2900
# 610      1.0         3+          1            No             4106
# 611      1.0          1          1            No             8072
# 612      1.0          2          1            No             7583
# 613      0.0          0          1           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# ...

# %%
X = df [ [
    'Married',
    'Dependents',
    'Education',
    'ApplicantIncome',
    'CoapplicantIncome',
    'LoanAmount',
    'Loan_Amount_Term',
    'Credit_History',
    'Property_Area_Rural',
    'Property_Area_Semiurban',
    'Property_Area_Urban',
]]
X
# Out:
#      Married  Dependents  Education  ApplicantIncome  CoapplicantIncome  \
# 0        0.0         0.0          1             5849                0.0
# 1        1.0         1.0          1             4583             1508.0
# 2        1.0         0.0          1             3000                0.0
# 3        1.0         0.0          0             2583             2358.0
# 4        0.0         0.0          1             6000                0.0
# ..       ...         ...        ...              ...                ...
# 609      0.0         0.0          1             2900                0.0
# 610      1.0         3.0          1             4106                0.0
# 611      1.0         1.0          1             8072              240.0
# 612      1.0         2.0          1             7583                0.0
# 613      0.0         0.0          1             4583                0.0
#
#      LoanAmount  Loan_Amount_Term  Credit_History  Property_Area_Rural  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  611 non-null    float64
#  1   Dependents               599 non-null    object
#  2   Education                614 non-null    int64
#  3   ApplicantIncome          614 non-null    int64
#  4   CoapplicantIncome        614 non-null    float64
#  5   LoanAmount               614 non-null    float64
#  6   Loan_Amount_Term         614 non-null    float64
#  7   Credit_History           614 non-null    float64
#  8   Property_Area_Rural      614 non-null    bool
#  9   Property_Area_Semiurban  614 non-null    bool
#  10  Property_Area_Urban      614 non-null    bool
# dtypes: bool(3), float64(5), int64(2), object(1)
# memory usage: 40.3+ KB

# %%
X.loc[X['Dependents'].isna(), 'Dependents'] = X['Dependents'].mode() [0]

# %%
X.loc[X['Married'].isna(), 'Married'] = X['Married'].mode() [0]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  614 non-null    float64
#  1   Dependents               614 non-null    object
#  2   Education                614 non-null    int64
#  3   ApplicantIncome          614 non-null    int64
#  4   CoapplicantIncome        614 non-null    float64
#  5   LoanAmount               614 non-null    float64
#  6   Loan_Amount_Term         614 non-null    float64
#  7   Credit_History           614 non-null    float64
#  8   Property_Area_Rural      614 non-null    bool
#  9   Property_Area_Semiurban  614 non-null    bool
#  10  Property_Area_Urban      614 non-null    bool
# dtypes: bool(3), float64(5), int64(2), object(1)
# memory usage: 40.3+ KB

# %%
y = df['Loan_Status'].map({'Y':1, 'N':0})
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  611 non-null    float64
#  1   Dependents               599 non-null    float64
#  2   Education                614 non-null    int64
#  3   ApplicantIncome          614 non-null    int64
#  4   CoapplicantIncome        614 non-null    float64
#  5   LoanAmount               614 non-null    float64
#  6   Loan_Amount_Term         614 non-null    float64
#  7   Credit_History           614 non-null    float64
#  8   Property_Area_Rural      614 non-null    bool
#  9   Property_Area_Semiurban  614 non-null    bool
#  10  Property_Area_Urban      614 non-null    bool
# dtypes: bool(3), float64(6), int64(2)
# memory usage: 40.3 KB

# %%
model = KNeighborsClassifier()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-80fc784234fd> in <cell line: 2>()
#       1 model = KNeighborsClassifier()
# ----> 2 model.fit(X, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#     216
#     217     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     452         if self._get_tags()["requires_y"]:
#     453             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 454                 X, y = self._validate_data(
#     455                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     456                 )
#
# ...

# %%
model.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-722473bfeded> in <cell line: 1>()
# ----> 1 model.score(X, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     666         from .metrics import accuracy_score
#     667
# --> 668         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     669
#     670     def _more_tags(self):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     232             # In that case, we do not need the distances to perform
#     233             # the weighting so we do not compute them.
# --> 234             neigh_ind = self.kneighbors(X, return_distance=False)
#     235             neigh_dist = None
#     236         else:
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X, y)
model.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-f760461d9b51> in <cell line: 3>()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 model = RandomForestClassifier()
# ----> 3 model.fit(X, y)
#       4 model.score(X, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     343         if issparse(y):
#     344             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345         X, y = self._validate_data(
#     346             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
print(model.score(X.train, y_train))
print(model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-0b91b5123875> in <cell line: 2>()
#       1 model = RandomForestClassifier()
# ----> 2 model.fit(X_train, y_train)
#       3 print(model.score(X.train, y_train))
#       4 print(model.score(X_test, y_test))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     343         if issparse(y):
#     344             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345         X, y = self._validate_data(
#     346             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
# ...
